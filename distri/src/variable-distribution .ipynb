# %%
# a bit of import
import numpy as np
import scipy

import matplotlib.pyplot as plt

# %%
# a random variable
randomX = np.random.rand(100)

# %%
randomX
# Out:
# array([ 0.23138797,  0.077128  ,  0.94108858,  0.36781294,  0.36281857,
#         0.13428896,  0.61508679,  0.08004379,  0.04987542,  0.87218719,
#         0.09336806,  0.28188815,  0.55442569,  0.06635382,  0.48198478,
#         0.74642356,  0.40772541,  0.62273862,  0.62952362,  0.35388796,
#         0.51263069,  0.19910249,  0.00371061,  0.52298656,  0.68491264,
#         0.30583985,  0.50025353,  0.82273138,  0.49720852,  0.6327032 ,
#         0.86976871,  0.03854346,  0.12526912,  0.13491698,  0.0196945 ,
#         0.24058873,  0.87114772,  0.16039355,  0.94420957,  0.87188247,
#         0.61143465,  0.14567695,  0.4756819 ,  0.27882451,  0.01396107,
#         0.06406106,  0.21253122,  0.44451751,  0.15944445,  0.20686215,
#         0.79520424,  0.98294239,  0.73141811,  0.7928412 ,  0.37008999,
#         0.01936351,  0.07912996,  0.58686785,  0.57764594,  0.61935533,
#         0.05592245,  0.89535157,  0.94153675,  0.6811422 ,  0.13870568,
# ...

# %%
plt.plot(randomX)
plt.show()

# %%
yOfX

plt.plot()

# [0    ... .........                             ....         ...   1]
